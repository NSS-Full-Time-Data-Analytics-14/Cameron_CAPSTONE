# %%
import pandas as pd
import numpy as np

# %%
tn_torn = pd.read_csv("../data/Tennessean_tornado_data.csv")

# %%
tn_torn
# Out:
#                    Date      Time  Year EF Scale  Path Length (in miles)  \
# 0     February 13, 1950   1:00 AM  1950      EF1                    0.20
# 1     February 13, 1950   2:00 AM  1950      EF2                    0.20
# 2        March 27, 1950  15:00 PM  1950      EF1                    0.20
# 3     November 14, 1951  22:00 PM  1951      EF2                    0.20
# 4     February 13, 1952  17:00 PM  1952      EF2                    0.30
# ...                 ...       ...   ...      ...                     ...
# 1573        May 8, 2024  20:02 PM  2024      EF1                    1.38
# 1574        May 9, 2024  12:39 AM  2024      EF1                    4.34
# 1575       May 14, 2024  15:16 PM  2024      EF0                    3.62
# 1576       May 26, 2024  23:55 PM  2024      EF1                   11.00
# 1577      July 29, 2024  13:24 PM  2024      EF0                    3.34
#
#       Width (in feet) Injury  Fatality  Property Damage Crops Damage  \
# ...

# %%
tn_torn.dtypes
# Out:
# Date                       object
# Time                       object
# Year                        int64
# EF Scale                   object
# Path Length (in miles)    float64
# Width (in feet)           float64
# Injury                     object
# Fatality                  float64
# Property Damage           float64
# Crops Damage               object
# commnets                  float64
# Link                       object
# dtype: object

# %%
tn_torn['Time'] = tn_torn['Time'].str.strip('AM')
tn_torn['Time'] = tn_torn['Time'].str.strip('PM')
tn_torn['Time']
# Out:
# 0        1:00
# 1        2:00
# 2       15:00
# 3       22:00
# 4       17:00
#          ...
# 1573    20:02
# 1574    12:39
# 1575    15:16
# 1576    23:55
# 1577    13:24
# Name: Time, Length: 1578, dtype: object

# %%
tn_torn.head()
# Out:
#                 Date    Time  Year EF Scale  Path Length (in miles)  \
# 0  February 13, 1950   1:00   1950      EF1                     0.2
# 1  February 13, 1950   2:00   1950      EF2                     0.2
# 2     March 27, 1950  15:00   1950      EF1                     0.2
# 3  November 14, 1951  22:00   1951      EF2                     0.2
# 4  February 13, 1952  17:00   1952      EF2                     0.3
#
#    Width (in feet) Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0              7.0      8       0.0           2500.0          NaN       NaN
# 1              7.0      1       9.0          25000.0          NaN       NaN
# 2              7.0      0       0.0           2500.0          NaN       NaN
# 3              7.0      0       0.0          25000.0          NaN       NaN
# 4            300.0      0       0.0          25000.0          NaN       NaN
#
#                          Link
# 0  Feb. 13, 1950 01:00 AM CST
# 1  Feb. 13, 1950 02:00 AM CST
# ...

# %%
tn_torn.dtypes
# Out:
# Date                       object
# Time                       object
# Year                        int64
# EF Scale                   object
# Path Length (in miles)    float64
# Width (in feet)           float64
# Injury                     object
# Fatality                  float64
# Property Damage           float64
# Crops Damage               object
# commnets                  float64
# Link                       object
# dtype: object

# %%
tn_torn['Date'] = pd.to_datetime(tn_torn['Date'])
tn_torn
# Out:
#            Date    Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00   1950      EF1                    0.20
# 1    1950-02-13   2:00   1950      EF2                    0.20
# 2    1950-03-27  15:00   1950      EF1                    0.20
# 3    1951-11-14  22:00   1951      EF2                    0.20
# 4    1952-02-13  17:00   1952      EF2                    0.30
# ...         ...     ...   ...      ...                     ...
# 1573 2024-05-08  20:02   2024      EF1                    1.38
# 1574 2024-05-09  12:39   2024      EF1                    4.34
# 1575 2024-05-14  15:16   2024      EF0                    3.62
# 1576 2024-05-26  23:55   2024      EF1                   11.00
# 1577 2024-07-29  13:24   2024      EF0                    3.34
#
#       Width (in feet) Injury  Fatality  Property Damage Crops Damage  \
# 0                 7.0      8       0.0           2500.0          NaN
# ...

# %%
tn_torn['Property Damage'] = tn_torn['Property Damage'].fillna(0)
tn_torn['Crops Damage'] = tn_torn['Crops Damage'].fillna(0)

tn_torn
# Out:
#            Date    Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00   1950      EF1                    0.20
# 1    1950-02-13   2:00   1950      EF2                    0.20
# 2    1950-03-27  15:00   1950      EF1                    0.20
# 3    1951-11-14  22:00   1951      EF2                    0.20
# 4    1952-02-13  17:00   1952      EF2                    0.30
# ...         ...     ...   ...      ...                     ...
# 1573 2024-05-08  20:02   2024      EF1                    1.38
# 1574 2024-05-09  12:39   2024      EF1                    4.34
# 1575 2024-05-14  15:16   2024      EF0                    3.62
# 1576 2024-05-26  23:55   2024      EF1                   11.00
# 1577 2024-07-29  13:24   2024      EF0                    3.34
#
#       Width (in feet) Injury  Fatality  Property Damage Crops Damage  \
# 0                 7.0      8       0.0           2500.0            0
# ...

# %%
tn_torn['month'] = tn_torn['Date'].dt.month.astype(str)
tn_torn.head(3)
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST   2.0
# 1  Feb. 13, 1950 02:00 AM CST   2.0
# 2  Mar. 27, 1950 15:00 PM CST   3.0

# %%
tn_torn['month'] = tn_torn['month'].str.replace('.0','')
tn_torn.head(3)
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST     2
# 1  Feb. 13, 1950 02:00 AM CST     2
# 2  Mar. 27, 1950 15:00 PM CST     3

# %%
tn_torn = tn_torn.loc[~((tn_torn['Date'].isna()) & (tn_torn['Time'].isna()) & (tn_torn['Year'] == 1900) & (tn_torn['EF Scale'].isna()) & (tn_torn['Path Length (in miles)'].isna()))]

# %%
tn_torn = tn_torn.loc[~(tn_torn['Year'] == '1900')]
tn_torn.head()
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
# 3 1951-11-14  22:00   1951      EF2                     0.2              7.0
# 4 1952-02-13  17:00   1952      EF2                     0.3            300.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
# 3      0       0.0          25000.0            0       NaN
# 4      0       0.0          25000.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST     2
# 1  Feb. 13, 1950 02:00 AM CST     2
# ...

# %%
tn_torn = tn_torn.loc[~(tn_torn['EF Scale'] == 0)]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
### Tornadoes GROUPED BY EF RATING

# %%
tornado_by_ef = tn_torn['EF Scale'].value_counts().reset_index()
tornado_by_ef
# Out:
#   EF Scale  count
# 0      EF1    600
# 1      EF0    496
# 2      EF2    307
# 3      EF3    120
# 4      EF4     53
# 5      EF5      1

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')
 
if __name__ == '__main__':    #INDENT EVERYTHING AFTER if !!!
   
    
    x = tornado_by_ef['EF Scale']
    y = tornado_by_ef['count']
     
     
    plt.figure(figsize = (10, 5))
    plt.bar(x, y, color = "blue", edgecolor = 'black')
     
    addlabels(x, y)
    plt.title("Tornadoes By EF Rating", fontweight = 'bold')  
    plt.xlabel(" ")
    plt.ylabel("Number of Admissions")
    plt.ylim(0,625)
    plt.xticks(fontweight = 'bold', rotation= 60)
     
    plt.savefig('counts_by_ef.png',bbox_inches = 'tight')    
    plt.show()

# %%
#tn_torn['EF Scale'].value_counts().plot(kind = 'bar', figsize = (10,6), color = 'blue', edgecolor = 'black') 
                                                                                   
#plt.xticks(rotation = 70, fontsize = 12, fontweight = 'bold')  
#plt.ylim(0, 650)                           
#plt.title('Tornadoes spotted', fontsize = 14, fontweight = 'bold')

# %%
#EF 5 sighting

# %%
tn_torn.head()
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
# 3 1951-11-14  22:00   1951      EF2                     0.2              7.0
# 4 1952-02-13  17:00   1952      EF2                     0.3            300.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
# 3      0       0.0          25000.0            0       NaN
# 4      0       0.0          25000.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST     2
# 1  Feb. 13, 1950 02:00 AM CST     2
# ...

# %%
import seaborn as sns

# %%
tn_torn.loc[tn_torn['Crops Damage']== 'A tornado touched down along Highway 225 and Silerton Road near Montezuma and moved southeast for roughly 2 miles. Six homes were damaged with two sustaining significant damage. A roof of a church sustained minor damage. A few farm sheds were damaged as well. A camper and boat was destroyed. Trees were snapped in the area and a few vehicles sustained shattered windows. A cotton module compress was also destroyed. The tornado lifted along Cecil Thomas Road.']= 0
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_30664\2926418147.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   tn_torn.loc[tn_torn['Crops Damage']== 'A tornado touched down along Highway 225 and Silerton Road near Montezuma and moved southeast for roughly 2 miles. Six homes were damaged with two sustaining significant damage. A roof of a church sustained minor damage. A few farm sheds were damaged as well. A camper and boat was destroyed. Trees were snapped in the area and a few vehicles sustained shattered windows. A cotton module compress was also destroyed. The tornado lifted along Cecil Thomas Road.']= 0

# %%
tn_torn['Fatality'] = tn_torn['Fatality'].fillna(0)
tn_torn['Fatality'] = tn_torn['Fatality'].astype(int)

# %%
tn_torn['Property Damage'] = tn_torn['Property Damage'].astype(int)
tn_torn['Property Damage'] = tn_torn['Property Damage'].fillna(0)

# %%
tn_torn['Injury'] = tn_torn['Injury'].str.replace(' (1)', '')

# %%
tn_torn['Injury'] = tn_torn['Injury'].fillna(0)

# %%
tn_torn['Injury'] = tn_torn['Injury'].astype(int)

# %%
def give_me_decade_please(Year):
    if 1950 <= Year <= 1959:
        return '1950s'
    elif 1960 <= Year <= 1969:
        return '1960s'
    elif 1970 <= Year <= 1979:
        return '1970s'
    elif 1980 <= Year <= 1989:
        return '1980s'
    elif 1990 <= Year <= 1999:
        return '1990s'
    elif 2000 <= Year <= 2009:
        return '2000s'
    elif 2010 <= Year <= 2019:
        return '2010s'
    elif 2020 <= Year <= 2029:
        return '2020s'
    else:
        return 'Unknown'

tn_torn['Decade'] = tn_torn['Year'].apply(give_me_decade_please)
tn_torn
# Out:
#                      Date    Time  Year EF Scale  Path Length (in miles)  \
# 0     1950-02-13 00:00:00   1:00   1950      EF1                    0.20
# 1     1950-02-13 00:00:00   2:00   1950      EF2                    0.20
# 2     1950-03-27 00:00:00  15:00   1950      EF1                    0.20
# 3     1951-11-14 00:00:00  22:00   1951      EF2                    0.20
# 4     1952-02-13 00:00:00  17:00   1952      EF2                    0.30
# ...                   ...     ...   ...      ...                     ...
# 1573  2024-05-08 00:00:00  20:02   2024      EF1                    1.38
# 1574  2024-05-09 00:00:00  12:39   2024      EF1                    4.34
# 1575  2024-05-14 00:00:00  15:16   2024      EF0                    3.62
# 1576  2024-05-26 00:00:00  23:55   2024      EF1                   11.00
# 1577  2024-07-29 00:00:00  13:24   2024      EF0                    3.34
#
#       Width (in feet)  Injury  Fatality  Property Damage Crops Damage  \
# ...

# %%
tn_torn.to_csv('tn_torn.csv', index=False)

# %%
tn_torn['Date'] = pd.to_datetime(tn_torn['Date'])

# %%
tn_torn['total_damagee'] = tn_torn['Property Damage'] + tn_torn['Crops Damage']
tn_torn
# Out:
#            Date   Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00  1950      EF1                    0.20
# 1    1950-02-13   2:00  1950      EF2                    0.20
# 2    1950-03-27  15:00  1950      EF1                    0.20
# 3    1951-11-14  22:00  1951      EF2                    0.20
# 4    1952-02-13  17:00  1952      EF2                    0.30
# ...         ...    ...   ...      ...                     ...
# 1573 2024-05-08  20:02  2024      EF1                    1.38
# 1574 2024-05-09  12:39  2024      EF1                    4.34
# 1575 2024-05-14  15:16  2024      EF0                    3.62
# 1576 2024-05-26  23:55  2024      EF1                   11.00
# 1577 2024-07-29  13:24  2024      EF0                    3.34
#
#       Width (in feet)  Injury  Fatality  Property Damage  Crops Damage  \
# 0                 7.0       8         0             2500             0
# 1                 7.0       1         9            25000             0
# ...

# %%
# TORNADO Reports BY Year

# %%
torns_yearly = tn_torn.groupby('Year').size().reset_index(name = 'tornado_reports')
type(torns_yearly)
# Out:
# pandas.core.frame.DataFrame

# %%
torns_yearly = torns_yearly.drop(0).reset_index()
torns_yearly
# Out:
#     index  Year  tornado_reports
# 0       1  1950                3
# 1       2  1951                1
# 2       3  1952               25
# 3       4  1953               16
# 4       5  1954                2
# ..    ...   ...              ...
# 69     70  2020               41
# 70     71  2021               97
# 71     72  2022                6
# 72     73  2023               59
# 73     74  2024               14
#
# [74 rows x 3 columns]

# %%
Injuries_per_year = tn_torn.groupby('Year')['Injury'].sum().reset_index()
Injuries_per_year = Injuries_per_year.drop(0).reset_index()
Injuries_per_year = Injuries_per_year.reset_index(drop = True)
Injuries_per_year = Injuries_per_year.drop(columns=['index'])
Injuries_per_year
# Out:
#     Year  Injury
# 0   1950       9
# 1   1951       0
# 2   1952     659
# 3   1953      34
# 4   1954       4
# ..   ...     ...
# 69  2020     337
# 70  2021      43
# 71  2022       0
# 72  2023     149
# 73  2024      13
#
# [74 rows x 2 columns]

# %%
#injuries per year

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x="Year", y="Injury", data = Injuries_per_year, color = 'red', edgecolor= 'yellow')

plt.title("Injuries Caused By Tornadoes", fontsize=16)
plt.xlabel("Year", fontsize=12, fontweight = 'bold')
plt.ylabel("Injuries", fontsize=12, fontweight = 'bold')
plt.xticks(rotation = 90)  
plt.tight_layout();
plt.savefig('injuries.png', bbox_inches = 'tight')

# %%
# Deaths per Year

# %%
fatalities_per_year = tn_torn.groupby('Year')['Fatality'].sum().reset_index()
fatalities_per_year.sort_values(by = 'Fatality', ascending = False).head()
fatalities_per_year = fatalities_per_year.drop(0)
fatalities_per_year = fatalities_per_year.rename(columns = {'Fatality' : 'Deaths'})
fatalities_per_year.head(7)
# Out:
#    Year  Deaths
# 1  1950       9
# 2  1951       0
# 3  1952      75
# 4  1953       4
# 5  1954       0
# 6  1955       0
# 7  1956       3

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x="Year", y="Deaths", data = fatalities_per_year, palette="plasma")

plt.title("Deaths Caused by Tornadoes", fontsize=16)
plt.xlabel("Year", fontsize=12, fontweight = 'bold')
plt.ylabel("Deaths", fontsize=12,fontweight = 'bold')
plt.xticks(rotation = 95)  
plt.tight_layout()

plt.savefig('deaths_by year.png', bbox_inches = 'tight')
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_30664\1547089305.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Year", y="Deaths", data = fatalities_per_year, palette="plasma")

# %%
fatalities_per_decade = tn_torn.groupby('Decade')['Fatality'].sum().reset_index()
fatalities_per_decade = fatalities_per_decade[fatalities_per_decade['Decade'] != 'Unknown']

fatalities_per_decade
# Out:
#   Decade  Fatality
# 0  1950s        91
# 1  1960s        11
# 2  1970s        59
# 3  1980s         8
# 4  1990s        29
# 5  2000s       100
# 6  2010s        43
# 7  2020s        49

# %%
tn_torn = tn_torn.drop(columns = 'commnets')
tn_torn.head(1)
# Out:
#         Date   Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13  1:00   1950      EF1                     0.2              7.0
#
#    Injury  Fatality  Property Damage Crops Damage                        Link  \
# 0       8         0             2500            0  Feb. 13, 1950 01:00 AM CST
#
#   month Decade
# 0     2  1950s

# %%
injuries_per_decade = tn_torn.groupby('Decade')['Injury'].sum().reset_index()
injuries_per_decade = injuries_per_decade[injuries_per_decade['Decade'] != 'Unknown']

injuries_per_decade
# Out:
#   Decade  Injury
# 0  1950s     817
# 1  1960s     146
# 2  1970s    1261
# 3  1980s     142
# 4  1990s     614
# 5  2000s     753
# 6  2010s     586
# 7  2020s     542

# %%
fig, ax = plt.subplots(figsize=(12, 12))  
sns.lineplot(data=fatalities_per_decade, x="Decade", y="Fatality", color='black', ax=ax, label='Fatalities')
sns.lineplot(data=injuries_per_decade, x="Decade", y="Injury", color='red', ax=ax, label='Injuries')

plt.xlabel(" ")
plt.xticks(fontweight = "bold")

plt.savefig('linegraph_deaths_injuries.png', bbox_inches = 'tight')

# %%
# HOW DO THEY CORRELATE

# %%
deaths_injuries_merged = pd.merge(fatalities_per_decade, injuries_per_decade, on = "Decade", how = 'inner')
deaths_injuries_merged

deaths_injuries_merged
# Out:
#   Decade  Fatality  Injury
# 0  1950s        91     817
# 1  1960s        11     146
# 2  1970s        59    1261
# 3  1980s         8     142
# 4  1990s        29     614
# 5  2000s       100     753
# 6  2010s        43     586
# 7  2020s        49     542

# %%
merge_corr = deaths_injuries_merged[['Fatality', 'Injury']].corr()
merge_corr
# Out:
#           Fatality    Injury
# Fatality  1.000000  0.688546
# Injury    0.688546  1.000000

# %%
tn_torn['Crops Damage'] = tn_torn['Crops Damage'].astype(int)
tn_torn['month'] = tn_torn['month'].astype(int)

# %%
tn_torn.dtypes
# Out:
# Date                      datetime64[ns]
# Time                              object
# Year                               int64
# EF Scale                          object
# Path Length (in miles)           float64
# Width (in feet)                  float64
# Injury                             int32
# Fatality                           int32
# Property Damage                    int32
# Crops Damage                       int32
# Link                              object
# month                              int32
# Decade                            object
# dtype: object

# %%
tn_torn['Time'] = tn_torn['Time'].str.strip()

# %%
tn_torn.dtypes
# Out:
# Date                      datetime64[ns]
# Time                              object
# Year                               int64
# EF Scale                          object
# Path Length (in miles)           float64
# Width (in feet)                  float64
# Injury                             int32
# Fatality                           int32
# Property Damage                    int32
# Crops Damage                       int32
# Link                              object
# month                              int32
# Decade                            object
# dtype: object

# %%
# MOST COMMON TIMES PER YEAR

# %%
def get_month_name(month):
    if month == 1:
        return "January"
    elif month == 2:
        return "February"
    elif month == 3:
        return "March"
    elif month == 4:
        return "April"
    elif month == 5:
        return "May"
    elif month == 6:
        return "June"
    elif month == 7:
        return "July"
    elif month == 8:
        return "August"
    elif month == 9:
        return "September"
    elif month == 10:
        return "October"
    elif month == 11:
        return "November"
    elif month == 12:
        return "December"
    else:
        return "something_else"

tn_torn['month_name'] = tn_torn['month'].apply(get_month_name)

tn_torn[['month', 'month_name']].head()
# Out:
#    month month_name
# 0      2   February
# 1      2   February
# 2      3      March
# 3     11   November
# 4      2   February

# %%
tn_torn.loc[tn_torn.month_name == "something_else"]
# Out:
#            Date Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 1149 1970-01-01  NaN     0        0                     0.0              0.0
#
#       Injury  Fatality  Property Damage  Crops Damage Link  month   Decade  \
# 1149       0         0                0             0    0      0  Unknown
#
#       total_damagee      month_name
# 1149              0  something_else

# %%
common_months = tn_torn['month_name'].value_counts().reset_index()
common_months
# Out:
#         month_name  count
# 0            April    394
# 1              May    280
# 2            March    232
# 3         February    133
# 4         November    120
# 5          January    102
# 6         December    101
# 7             June     78
# 8          October     47
# 9             July     45
# 10          August     29
# 11       September     15
# 12  something_else      1

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6)) 

sns.barplot(data = common_months, x="month_name", y="count", color = 'blue', order = month_order)

plt.title("Monthly Sightings 1950 - Present", fontsize = 16, fontweight = "bold")
plt.xlabel("Month")
plt.ylabel("Sightings")
plt.xticks(rotation=45, fontweight = "bold")

plt.savefig('sightings_by_month.png', bbox_inches = 'tight');

# %%
tornado_sql = tn_torn.rename(columns={'Date': 'date','Time': 'time','Year': 'year','EF Scale': 'ef_scale',
    'Path Length (in miles)': 'path_length_mi','Width (in feet)': 'width_mi','Injury': 'injury','Fatality': 'fatality',
    'Property Damage': 'property_dmg','Crops Damage': 'crop_dmg', 'Link': 'link','month': 'month','Decade': 'decade'})

# %%
tornado_sql.to_csv('tornado_for_sql_v2.csv', index=False)

# %%
totals_df = pd.read_csv("../data/TN_total_tornado_data.csv")

# %%
totals_df.columns
# Out:
# Index(['Year', 'TN Total', 'West', 'Middle', 'East', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 't', 'w', 'm', 'e'],
#       dtype='object')

# %%
totals_df = totals_df.iloc[:, :5]

# %%
totals_df
# Out:
#     Year  TN Total  West  Middle  East
# 0   2024        19     2      15     2
# 1   2023        40    11      21     9
# 2   2022         5     4       1     0
# 3   2021        66    18      46     3
# 4   2020        35     9      21     6
# ..   ...       ...   ...     ...   ...
# 70  1954         2     2       0     0
# 71  1953        14    11       1     2
# 72  1952        16     7       8     1
# 73  1951         2     0       2     0
# 74  1950         3     2       1     0
#
# [75 rows x 5 columns]

# %%
totals_sorted = totals_df.sort_values(by = 'TN Total', ascending = False)
totals_sorted
# Out:
#     Year  TN Total  West  Middle  East
# 13  2011       106     6      38    62
# 3   2021        66    18      46     3
# 21  2003        50    21      27     2
# 11  2013        47     3      36     3
# 15  2009        46     7      24    15
# ..   ...       ...   ...     ...   ...
# 70  1954         2     2       0     0
# 55  1969         2     1       1     0
# 73  1951         2     0       2     0
# 62  1962         1     1       0     0
# 37  1987         1     1       0     0
#
# [75 rows x 5 columns]

# %%
totals = totals_df[["West", "Middle", "East"]].sum()
totals
# Out:
# West      416
# Middle    725
# East      257
# dtype: int64

# %%
labels = totals.index
sizes = totals.values

sns.set_theme(style="whitegrid")
sns.set_palette("GnBu_r")

plt.figure(figsize=(7, 7))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', textprops = {'fontweight': 'bold'})
plt.title("Total Tornadoes Per Grand Division", fontweight = 'bold', fontsize = 17)

plt.savefig('Grand_Divs.png', transparent = True, bbox_inches = 'tight')

plt.show()

# %%
# What years had the most tornadoes?
# Which years had the most property damage, and do those 2 questions correlate?

# %%
sns.set(style="whitegrid")


plt.figure(figsize=(15, 7))
sns.barplot(data = totals_sorted, x='Year', y='TN Total', palette='Blues_d')



plt.xlabel('Year')
plt.ylabel('Tornado Count')
plt.title('Tornadoes by Year', fontweight = 'bold')
plt.xticks(rotation= 85)

plt.savefig('total_tornado_per_year.png',bbox_inches = 'tight')
plt.tight_layout()
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_30664\1923315486.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data = totals_sorted, x='Year', y='TN Total', palette='Blues_d')

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(13, 7))
sns.lineplot(data = totals_sorted, x='Year', y='TN Total', palette='Blues_d')


plt.xlabel('Year')
plt.ylabel('Tornado Count')
plt.title('Tornadoes by Year', fontsize = 16, fontweight = 'bold')
plt.xticks(rotation= 85)

plt.savefig('linegraph_totals.png', bbox_inches = 'tight')
plt.tight_layout()
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_30664\950243903.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = totals_sorted, x='Year', y='TN Total', palette='Blues_d')

# %%
### OUTBREAKS EXPLORED

# %%
outbreaks_df = pd.read_csv("../data/tornado_outbreaks.csv")
outbreaks_df
# Out:
#     Rank               Date  tornado_count Max F/EF Rating  \
# 0      1     April 27, 2011             30             EF3
# 1      2      April 3, 1974             24             EF4
# 2      3   January 30, 2013             24             EF2
# 3      4        May 6, 1984             18             EF2
# 4      5  December 10, 2021             16             EF2
# 5      6       May 18, 1995             15             EF4
# 6      7        May 4, 2021             14             EF0
# 7      8   February 5, 2008             14             EF3
# 8      9        May 4, 2003             14              F3
# 9     10  November 15, 2005             13              F2
# 10    11     April 16, 1998             13              F5
#
#     # of Max Rated Tornadoes  Deaths
# 0                          1       0
# 1                          5      38
# 2                          3       0
# 3                          3       0
# 4                          4       0
# ...

# %%
outbreaks_df.columns
# Out:
# Index(['Rank', 'Date', 'tornado_count', 'Max F/EF Rating',
#        '# of Max Rated Tornadoes', 'Deaths'],
#       dtype='object')

# %%
outbreaks_df.dtypes
# Out:
# Rank                         int64
# Date                        object
# tornado_count                int64
# Max F/EF Rating             object
# # of Max Rated Tornadoes     int64
# Deaths                       int64
# dtype: object

# %%
outbreaks_df = outbreaks_df.rename(columns = {'Max F/EF Rating' : 'maximum_ef_reached' , '# of Max Rated Tornadoes' :'number_maxed_tornadoes'})
outbreaks_df
# Out:
#     Rank               Date  tornado_count maximum_ef_reached  \
# 0      1     April 27, 2011             30                EF3
# 1      2      April 3, 1974             24                EF4
# 2      3   January 30, 2013             24                EF2
# 3      4        May 6, 1984             18                EF2
# 4      5  December 10, 2021             16                EF2
# 5      6       May 18, 1995             15                EF4
# 6      7        May 4, 2021             14                EF0
# 7      8   February 5, 2008             14                EF3
# 8      9        May 4, 2003             14                 F3
# 9     10  November 15, 2005             13                 F2
# 10    11     April 16, 1998             13                 F5
#
#     number_maxed_tornadoes  Deaths
# 0                        1       0
# 1                        5      38
# 2                        3       0
# 3                        3       0
# 4                        4       0
# ...

# %%
outbreaks_df['maximum_ef_reached'] = outbreaks_df['maximum_ef_reached'].replace({'F2': 'EF2', 'F3': 'EF3', 'F5': 'EF5'})
outbreaks_df
# Out:
#     Rank               Date  tornado_count maximum_ef_reached  \
# 0      1     April 27, 2011             30                EF3
# 1      2      April 3, 1974             24                EF4
# 2      3   January 30, 2013             24                EF2
# 3      4        May 6, 1984             18                EF2
# 4      5  December 10, 2021             16                EF2
# 5      6       May 18, 1995             15                EF4
# 6      7        May 4, 2021             14                EF0
# 7      8   February 5, 2008             14                EF3
# 8      9        May 4, 2003             14                EF3
# 9     10  November 15, 2005             13                EF2
# 10    11     April 16, 1998             13                EF5
#
#     number_maxed_tornadoes  Deaths
# 0                        1       0
# 1                        5      38
# 2                        3       0
# 3                        3       0
# 4                        4       0
# ...

# %%
outbreaks_df['Deaths'] = outbreaks_df['Deaths'].replace({38: 45})

# %%
outbreaks_df['Date'] = pd.to_datetime(outbreaks_df['Date'])
outbreaks_df.head
# Out:
# <bound method NDFrame.head of     Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 0      1 2011-04-27             30                EF3                       1
# 1      2 1974-04-03             24                EF4                       5
# 2      3 2013-01-30             24                EF2                       3
# 3      4 1984-05-06             18                EF2                       3
# 4      5 2021-12-10             16                EF2                       4
# 5      6 1995-05-18             15                EF4                       1
# 6      7 2021-05-04             14                EF0                      14
# 7      8 2008-02-05             14                EF3                       1
# 8      9 2003-05-04             14                EF3                       1
# 9     10 2005-11-15             13                EF2                       4
# 10    11 1998-04-16             13                EF5                       1
#
# ...

# %%
injuries_damages_by_date = tn_torn.groupby('Date')[['Injury', 'total_damagee']].sum().reset_index()
injuries_damages_by_date.head()
# Out:
#         Date  Injury  total_damagee
# 0 1950-02-13       9          27500
# 1 1950-03-27       0           2500
# 2 1951-11-14       0          25000
# 3 1952-02-13      48        1050000
# 4 1952-02-29     316        2800000

# %%
from sqlalchemy import create_engine, text

# %%
tornado_sql_database = 'Tornado'    

tornado_connection_string = f"postgresql://postgres:postgres@localhost:5432/{tornado_sql_database}"

# %%
engine = create_engine(tornado_connection_string)

# %%
query_1 = '''SELECT ef_scale, ROUND(AVG(width_mi), 2) AS recorded_avg_size, ROUND(MAX(width_mi), 2) AS max_size, 
		ROUND(MIN(width_mi), 2) AS min_size
FROM tornado
GROUP BY ef_scale
ORDER BY recorded_avg_size DESC'''

# %%
with engine.connect() as connection:
    average_sizes = pd.read_sql(text(query_1), con = connection) 

average_sizes.head()
# Out:
#   ef_scale  recorded_avg_size  max_size  min_size
# 0      EF5            1760.00    1760.0    1760.0
# 1      EF4             541.36    1800.0      33.0
# 2      EF3             515.92    2000.0       7.0
# 3      EF2             293.02    1800.0       7.0
# 4      EF1             141.04    1300.0       3.0

# %%
#Averages of each EF rating

# %%
query_2 = '''SELECT ef_scale, COUNT(*), ROUND(AVG(path_length_mi),2) AS avg_path, ROUND(AVG(width_mi),2) AS avg_width_ft, 
		ROUND(AVG(property_dmg),2) AS avg_damage_cost, ROUND(AVG(injury)) AS avg_ouchies, ROUND(AVG(fatality)) AS avg_deaths,
  SUM(fatality) as total_deaths
FROM tornado
Group BY ef_scale
ORDER BY avg_width_ft DESC'''

# %%
with engine.connect() as connection:
    all_averages = pd.read_sql(text(query_2), con = connection) 

all_averages.head()
# Out:
#   ef_scale  count  avg_path  avg_width_ft  avg_damage_cost  avg_ouchies  \
# 0      EF5      1     22.70       1760.00       4000000.00         21.0
# 1      EF4     53     12.17        541.36       9639660.38         34.0
# 2      EF3    120     10.28        515.92      18616816.67         15.0
# 3      EF2    306      6.30        293.02       1297773.69          2.0
# 4      EF1    600      3.58        141.04        223804.22          1.0
#
#    avg_deaths  total_deaths
# 0         0.0             0
# 1         3.0           173
# 2         1.0           138
# 3         0.0            52
# 4         0.0            26

# %%
all_averages.dtypes
# Out:
# ef_scale            object
# count                int64
# avg_path           float64
# avg_width_ft       float64
# avg_damage_cost    float64
# avg_ouchies        float64
# avg_deaths         float64
# total_deaths         int64
# dtype: object

# %%
max_size_query = '''SELECT date, SUM(injury) AS injuries, MAX(width_mi) AS max_size_ft
FROM tornado
GROUP BY date'''

# %%
with engine.connect() as connection:
    max_size_per_date = pd.read_sql(text(max_size_query), con = connection) 

max_size_per_date.head()
# Out:
#          date  injuries  max_size_ft
# 0  1997-05-02         0        150.0
# 1  2004-10-18         2        300.0
# 2  1957-04-04        11         50.0
# 3  2011-06-24         0        100.0
# 4  1990-04-28         0         50.0

# %%
max_size_per_date['date'] = pd.to_datetime(max_size_per_date['date'])
max_size_per_date.dtypes
# Out:
# date           datetime64[ns]
# injuries                int64
# max_size_ft           float64
# dtype: object

# %%
outbreak_extended = pd.merge(outbreaks_df, max_size_per_date, left_on = 'Date', right_on = 'date', how = 'inner')
outbreak_extended
# Out:
#     Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 0      1 2011-04-27             30                EF3                       1
# 1      2 1974-04-03             24                EF4                       5
# 2      3 2013-01-30             24                EF2                       3
# 3      4 1984-05-06             18                EF2                       3
# 4      5 2021-12-10             16                EF2                       4
# 5      6 1995-05-18             15                EF4                       1
# 6      7 2021-05-04             14                EF0                      14
# 7      8 2008-02-05             14                EF3                       1
# 8      9 2003-05-04             14                EF3                       1
# 9     10 2005-11-15             13                EF2                       4
# 10    11 1998-04-16             13                EF5                       1
#
# ...

# %%
damages_by_date = injuries_damages_by_date.drop(columns = 'Injury')
damages_by_date
# Out:
#           Date  total_damagee
# 0   1950-02-13          27500
# 1   1950-03-27           2500
# 2   1951-11-14          25000
# 3   1952-02-13        1050000
# 4   1952-02-29        2800000
# ..         ...            ...
# 503 2024-05-08       14600000
# 504 2024-05-09           3000
# 505 2024-05-14         250000
# 506 2024-05-26          10000
# 507 2024-07-29         750000
#
# [508 rows x 2 columns]

# %%
outbreak_extended = pd.merge(outbreak_extended, damages_by_date, on= 'Date', how = 'inner')
outbreak_extended = outbreak_extended.drop(columns = 'date')

# %%
### EXpORTING OUTBREAKS TO SQL, mostly for fun

# %%
outbreak_extended
# Out:
#     Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 0      1 2011-04-27             30                EF3                       1
# 1      2 1974-04-03             24                EF4                       5
# 2      3 2013-01-30             24                EF2                       3
# 3      4 1984-05-06             18                EF2                       3
# 4      5 2021-12-10             16                EF2                       4
# 5      6 1995-05-18             15                EF4                       1
# 6      7 2021-05-04             14                EF0                      14
# 7      8 2008-02-05             14                EF3                       1
# 8      9 2003-05-04             14                EF3                       1
# 9     10 2005-11-15             13                EF2                       4
# 10    11 1998-04-16             13                EF5                       1
#
# ...

# %%
outbreak_extended= outbreak_extended.rename(columns = {'Rank' :'rank', 'Date': 'date','Deaths':'deaths', 'total_damagee': 'damage_cost' })

# %%
outbreak_extended.dtypes
# Out:
# rank                               int64
# date                      datetime64[ns]
# tornado_count                      int64
# maximum_ef_reached                object
# number_maxed_tornadoes             int64
# deaths                             int64
# injuries                           int64
# max_size_ft                      float64
# damage_cost                        int32
# casualties                         int64
# dtype: object

# %%
outbreak_extended.to_csv('outbreak_extended_for_sql.csv', index=False)

# %%
# EF SCALE STATS

# %%
#what is the most deadly

# %%
ef_deaths = tn_torn.groupby('EF Scale')['Fatality'].sum().reset_index()
ef_deaths = ef_deaths.drop(index = 0)
ef_deaths = ef_deaths.reset_index(drop=True)
ef_deaths
# Out:
#   EF Scale  Fatality
# 0      EF0         1
# 1      EF1        26
# 2      EF2        52
# 3      EF3       138
# 4      EF4       173
# 5      EF5         0

# %%
#What ef rating had the most injuries

# %%
ef_injury = tn_torn.groupby('EF Scale')['Injury'].sum().reset_index()
ef_injury = ef_injury.drop(index = 0)
ef_injury = ef_injury.reset_index(drop=True)
ef_injury
# Out:
#   EF Scale  Injury
# 0      EF0      33
# 1      EF1     456
# 2      EF2     679
# 3      EF3    1854
# 4      EF4    1818
# 5      EF5      21

# %%
ef_death_injury_merged_df = pd.merge(ef_deaths, ef_injury, on="EF Scale")
ef_death_injury_merged_df
# Out:
#   EF Scale  Fatality  Injury
# 0      EF0         1      33
# 1      EF1        26     456
# 2      EF2        52     679
# 3      EF3       138    1854
# 4      EF4       173    1818
# 5      EF5         0      21

# %%
x = np.arange(len(ef_death_injury_merged_df['EF Scale']))
bar_width = 0.35 

fig, ax = plt.subplots(figsize=(8, 6))
deaths = ax.bar(x - bar_width/2, ef_death_injury_merged_df['Fatality'], bar_width, label='Fatality', color='black')
injuries = ax.bar(x + bar_width/2, ef_death_injury_merged_df['Injury'], bar_width, label='Injury', color='blue')


ax.set_xlabel(' ')
plt.xticks(rotation = 60, fontweight = 'bold')
ax.set_ylabel('')
ax.set_title('Fatalities & Injuries for each EF Scale Rating',fontweight = 'bold')
ax.set_xticks(x)
ax.set_xticklabels(ef_death_injury_merged_df['EF Scale'])
ax.legend()


plt.savefig('ef_injuries_deaths.png', bbox_inches = 'tight')


plt.tight_layout()
plt.show()

# %%
#what Ef tornado causes more damage

# %%
ef_costs = tn_torn.groupby('EF Scale')['total_damagee'].sum().reset_index()
ef_costs = ef_costs.drop(index = 0)
ef_costs = ef_costs.reset_index(drop=True)

# %%
outbreak_extended
# Out:
#     Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 0      1 2011-04-27             30                EF3                       1
# 1      2 1974-04-03             24                EF4                       5
# 2      3 2013-01-30             24                EF2                       3
# 3      4 1984-05-06             18                EF2                       3
# 4      5 2021-12-10             16                EF2                       4
# 5      6 1995-05-18             15                EF4                       1
# 6      7 2021-05-04             14                EF0                      14
# 7      8 2008-02-05             14                EF3                       1
# 8      9 2003-05-04             14                EF3                       1
# 9     10 2005-11-15             13                EF2                       4
# 10    11 1998-04-16             13                EF5                       1
#
# ...

# %%
outbreak_extended['casualties'] = (outbreak_extended['Deaths'] + outbreak_extended['injuries'])
outbreak_extended
outbreak_extended.to_csv('outbreak_extended.csv', index=False)

# %%
outbreak_extended.sort_values(by = 'total_damagee', ascending = True)
# Out:
#     Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 3      4 1984-05-06             18                EF2                       3
# 6      7 2021-05-04             14                EF0                      14
# 2      3 2013-01-30             24                EF2                       3
# 5      6 1995-05-18             15                EF4                       1
# 9     10 2005-11-15             13                EF2                       4
# 1      2 1974-04-03             24                EF4                       5
# 4      5 2021-12-10             16                EF2                       4
# 0      1 2011-04-27             30                EF3                       1
# 8      9 2003-05-04             14                EF3                       1
# 10    11 1998-04-16             13                EF5                       1
# 7      8 2008-02-05             14                EF3                       1
#
# ...

# %%
### WHAT OUTBREAKS HAD THE MOST DEATHS

# %%
outbreak_extended.sort_values(by = "Deaths", ascending = False).head(1)
# Out:
#    Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 1     2 1974-04-03             24                EF4                       5
#
#    Deaths  injuries  max_size_ft  total_damagee  casualties
# 1      45       742        800.0       21542500         787

# %%
### WHAT OUTBREAK HAD THE MOST Injured

# %%
outbreak_extended.sort_values(by = "injuries", ascending = False).head(1)
# Out:
#    Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 1     2 1974-04-03             24                EF4                       5
#
#    Deaths  injuries  max_size_ft  total_damagee  casualties
# 1      45       742        800.0       21542500         787

# %%
### WHICH OUTBREAK HAD THE MOST COST IN DAMAGES

# %%
outbreak_extended.sort_values(by = "total_damagee", ascending = False).head(1)
# Out:
#    Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 7     8 2008-02-05             14                EF3                       1
#
#    Deaths  injuries  max_size_ft  total_damagee  casualties
# 7      22       148        880.0      266698000         170

# %%
### wHICH OUTbreak had the largest tornado

# %%
outbreak_extended.sort_values(by = "max_size_ft", ascending = False).head(1)
# Out:
#    Rank       Date  tornado_count maximum_ef_reached  number_maxed_tornadoes  \
# 4     5 2021-12-10             16                EF2                       4
#
#    Deaths  injuries  max_size_ft  total_damagee  casualties
# 4       0        34       1800.0       24135000          34

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x="Year", y="Fatality_rate", data = deaths_by_date, palette="plasma")

plt.title("Deaths Caused by Tornadoes", fontsize=16)
plt.xlabel("Year", fontsize=12, fontweight = 'bold')
plt.ylabel("Deaths", fontsize=12,fontweight = 'bold')
plt.xticks(rotation = 95)  
plt.tight_layout()

plt.savefig('deaths_by year.png', bbox_inches = 'tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 3
#       1 plt.figure(figsize=(12, 6))
# ----> 3 sns.barplot(x="Year", y="Fatality_rate", data = deaths_by_date, palette="plasma")
#       5 plt.title("Deaths Caused by Tornadoes", fontsize=16)
#       6 plt.xlabel("Year", fontsize=12, fontweight = 'bold')
#
# NameError: name 'deaths_by_date' is not defined
