# %%
import pandas as pd
import numpy as np

# %%
tn_torn = pd.read_csv("../data/Tennessean_tornado_data.csv")

# %%
tn_torn
# Out:
#                    Date      Time  Year EF Scale  Path Length (in miles)  \
# 0     February 13, 1950   1:00 AM  1950      EF1                    0.20
# 1     February 13, 1950   2:00 AM  1950      EF2                    0.20
# 2        March 27, 1950  15:00 PM  1950      EF1                    0.20
# 3     November 14, 1951  22:00 PM  1951      EF2                    0.20
# 4     February 13, 1952  17:00 PM  1952      EF2                    0.30
# ...                 ...       ...   ...      ...                     ...
# 1573        May 8, 2024  20:02 PM  2024      EF1                    1.38
# 1574        May 9, 2024  12:39 AM  2024      EF1                    4.34
# 1575       May 14, 2024  15:16 PM  2024      EF0                    3.62
# 1576       May 26, 2024  23:55 PM  2024      EF1                   11.00
# 1577      July 29, 2024  13:24 PM  2024      EF0                    3.34
#
#       Width (in feet) Injury  Fatality  Property Damage Crops Damage  \
# 0                 7.0      8       0.0           2500.0          NaN
# 1                 7.0      1       9.0          25000.0          NaN
# 2                 7.0      0       0.0           2500.0          NaN
# 3                 7.0      0       0.0          25000.0          NaN
# 4               300.0      0       0.0          25000.0          NaN
# ...               ...    ...       ...              ...          ...
# 1573            286.0      0       0.0              NaN          NaN
# 1574            300.0      0       0.0           3000.0          NaN
# 1575            100.0      0       0.0         250000.0          NaN
# 1576            550.0      0       0.0          10000.0          NaN
# 1577            100.0      0       0.0         750000.0          NaN
#
#       commnets                        Link
# 0          NaN  Feb. 13, 1950 01:00 AM CST
# 1          NaN  Feb. 13, 1950 02:00 AM CST
# 2          NaN  Mar. 27, 1950 15:00 PM CST
# 3          NaN  Nov. 14, 1951 22:00 PM CST
# 4          NaN  Feb. 13, 1952 17:00 PM CST
# ...        ...                         ...
# 1573       NaN  May. 08, 2024 20:02 PM CDT
# 1574       NaN  May. 09, 2024 00:39 AM CDT
# 1575       NaN  May. 14, 2024 15:16 PM CDT
# 1576       NaN  May. 26, 2024 23:55 PM CDT
# 1577       NaN  Jul. 29, 2024 13:24 PM CDT
#
# [1578 rows x 12 columns]

# %%
tn_torn.dtypes
# Out:
# Date                       object
# Time                       object
# Year                        int64
# EF Scale                   object
# Path Length (in miles)    float64
# Width (in feet)           float64
# Injury                     object
# Fatality                  float64
# Property Damage           float64
# Crops Damage               object
# commnets                  float64
# Link                       object
# dtype: object

# %%
tn_torn['Time'] = tn_torn['Time'].str.strip('AM')
tn_torn['Time'] = tn_torn['Time'].str.strip('PM')
tn_torn['Time']
# Out:
# 0        1:00
# 1        2:00
# 2       15:00
# 3       22:00
# 4       17:00
#          ...
# 1573    20:02
# 1574    12:39
# 1575    15:16
# 1576    23:55
# 1577    13:24
# Name: Time, Length: 1578, dtype: object

# %%
tn_torn.head()
# Out:
#                 Date    Time  Year EF Scale  Path Length (in miles)  \
# 0  February 13, 1950   1:00   1950      EF1                     0.2
# 1  February 13, 1950   2:00   1950      EF2                     0.2
# 2     March 27, 1950  15:00   1950      EF1                     0.2
# 3  November 14, 1951  22:00   1951      EF2                     0.2
# 4  February 13, 1952  17:00   1952      EF2                     0.3
#
#    Width (in feet) Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0              7.0      8       0.0           2500.0          NaN       NaN
# 1              7.0      1       9.0          25000.0          NaN       NaN
# 2              7.0      0       0.0           2500.0          NaN       NaN
# 3              7.0      0       0.0          25000.0          NaN       NaN
# 4            300.0      0       0.0          25000.0          NaN       NaN
#
#                          Link
# 0  Feb. 13, 1950 01:00 AM CST
# 1  Feb. 13, 1950 02:00 AM CST
# 2  Mar. 27, 1950 15:00 PM CST
# 3  Nov. 14, 1951 22:00 PM CST
# 4  Feb. 13, 1952 17:00 PM CST

# %%
tn_torn.dtypes
# Out:
# Date                       object
# Time                       object
# Year                        int64
# EF Scale                   object
# Path Length (in miles)    float64
# Width (in feet)           float64
# Injury                     object
# Fatality                  float64
# Property Damage           float64
# Crops Damage               object
# commnets                  float64
# Link                       object
# dtype: object

# %%
tn_torn['Date'] = pd.to_datetime(tn_torn['Date'])
tn_torn
# Out:
#            Date    Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00   1950      EF1                    0.20
# 1    1950-02-13   2:00   1950      EF2                    0.20
# 2    1950-03-27  15:00   1950      EF1                    0.20
# 3    1951-11-14  22:00   1951      EF2                    0.20
# 4    1952-02-13  17:00   1952      EF2                    0.30
# ...         ...     ...   ...      ...                     ...
# 1573 2024-05-08  20:02   2024      EF1                    1.38
# 1574 2024-05-09  12:39   2024      EF1                    4.34
# 1575 2024-05-14  15:16   2024      EF0                    3.62
# 1576 2024-05-26  23:55   2024      EF1                   11.00
# 1577 2024-07-29  13:24   2024      EF0                    3.34
#
#       Width (in feet) Injury  Fatality  Property Damage Crops Damage  \
# 0                 7.0      8       0.0           2500.0          NaN
# 1                 7.0      1       9.0          25000.0          NaN
# 2                 7.0      0       0.0           2500.0          NaN
# 3                 7.0      0       0.0          25000.0          NaN
# 4               300.0      0       0.0          25000.0          NaN
# ...               ...    ...       ...              ...          ...
# 1573            286.0      0       0.0              NaN          NaN
# 1574            300.0      0       0.0           3000.0          NaN
# 1575            100.0      0       0.0         250000.0          NaN
# 1576            550.0      0       0.0          10000.0          NaN
# 1577            100.0      0       0.0         750000.0          NaN
#
#       commnets                        Link
# 0          NaN  Feb. 13, 1950 01:00 AM CST
# 1          NaN  Feb. 13, 1950 02:00 AM CST
# 2          NaN  Mar. 27, 1950 15:00 PM CST
# 3          NaN  Nov. 14, 1951 22:00 PM CST
# 4          NaN  Feb. 13, 1952 17:00 PM CST
# ...        ...                         ...
# 1573       NaN  May. 08, 2024 20:02 PM CDT
# 1574       NaN  May. 09, 2024 00:39 AM CDT
# 1575       NaN  May. 14, 2024 15:16 PM CDT
# 1576       NaN  May. 26, 2024 23:55 PM CDT
# 1577       NaN  Jul. 29, 2024 13:24 PM CDT
#
# [1578 rows x 12 columns]

# %%
tn_torn['Property Damage'] = tn_torn['Property Damage'].fillna(0)
tn_torn['Crops Damage'] = tn_torn['Crops Damage'].fillna(0)

tn_torn
# Out:
#            Date    Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00   1950      EF1                    0.20
# 1    1950-02-13   2:00   1950      EF2                    0.20
# 2    1950-03-27  15:00   1950      EF1                    0.20
# 3    1951-11-14  22:00   1951      EF2                    0.20
# 4    1952-02-13  17:00   1952      EF2                    0.30
# ...         ...     ...   ...      ...                     ...
# 1573 2024-05-08  20:02   2024      EF1                    1.38
# 1574 2024-05-09  12:39   2024      EF1                    4.34
# 1575 2024-05-14  15:16   2024      EF0                    3.62
# 1576 2024-05-26  23:55   2024      EF1                   11.00
# 1577 2024-07-29  13:24   2024      EF0                    3.34
#
#       Width (in feet) Injury  Fatality  Property Damage Crops Damage  \
# 0                 7.0      8       0.0           2500.0            0
# 1                 7.0      1       9.0          25000.0            0
# 2                 7.0      0       0.0           2500.0            0
# 3                 7.0      0       0.0          25000.0            0
# 4               300.0      0       0.0          25000.0            0
# ...               ...    ...       ...              ...          ...
# 1573            286.0      0       0.0              0.0            0
# 1574            300.0      0       0.0           3000.0            0
# 1575            100.0      0       0.0         250000.0            0
# 1576            550.0      0       0.0          10000.0            0
# 1577            100.0      0       0.0         750000.0            0
#
#       commnets                        Link
# 0          NaN  Feb. 13, 1950 01:00 AM CST
# 1          NaN  Feb. 13, 1950 02:00 AM CST
# 2          NaN  Mar. 27, 1950 15:00 PM CST
# 3          NaN  Nov. 14, 1951 22:00 PM CST
# 4          NaN  Feb. 13, 1952 17:00 PM CST
# ...        ...                         ...
# 1573       NaN  May. 08, 2024 20:02 PM CDT
# 1574       NaN  May. 09, 2024 00:39 AM CDT
# 1575       NaN  May. 14, 2024 15:16 PM CDT
# 1576       NaN  May. 26, 2024 23:55 PM CDT
# 1577       NaN  Jul. 29, 2024 13:24 PM CDT
#
# [1578 rows x 12 columns]

# %%
tn_torn['month'] = tn_torn['Date'].dt.month.astype(str)
tn_torn.head(3)
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST   2.0
# 1  Feb. 13, 1950 02:00 AM CST   2.0
# 2  Mar. 27, 1950 15:00 PM CST   3.0

# %%
tn_torn['month'] = tn_torn['month'].str.replace('.0','')
tn_torn.head(3)
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST     2
# 1  Feb. 13, 1950 02:00 AM CST     2
# 2  Mar. 27, 1950 15:00 PM CST     3

# %%
tn_torn = tn_torn.loc[~((tn_torn['Date'].isna()) & (tn_torn['Time'].isna()) & (tn_torn['Year'] == 1900) & (tn_torn['EF Scale'].isna()) & (tn_torn['Path Length (in miles)'].isna()))]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# %%
tornado_by_ef = tn_torn['EF Scale'].value_counts().reset_index()
tornado_by_ef
# Out:
#   EF Scale  count
# 0      EF1    600
# 1      EF0    496
# 2      EF2    307
# 3      EF3    120
# 4      EF4     53
# 5      EF5      1

# %%
tn_torn['EF Scale'].value_counts().plot(kind = 'bar', figsize = (10,6), color = 'red', edgecolor = 'black') 
                                                                                   
plt.xticks(rotation = 70, fontsize = 12, fontweight = 'bold')                                 
                            
plt.title('Tornadoes spotted', fontsize = 14, fontweight = 'bold');

# %%
tn_torn.head()
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
# 3 1951-11-14  22:00   1951      EF2                     0.2              7.0
# 4 1952-02-13  17:00   1952      EF2                     0.3            300.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
# 3      0       0.0          25000.0            0       NaN
# 4      0       0.0          25000.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST     2
# 1  Feb. 13, 1950 02:00 AM CST     2
# 2  Mar. 27, 1950 15:00 PM CST     3
# 3  Nov. 14, 1951 22:00 PM CST    11
# 4  Feb. 13, 1952 17:00 PM CST     2

# %%
import seaborn as sns

# %%
tn_torn = tn_torn.loc[~(tn_torn['Year'] == '1900')]
tn_torn.head()
# Out:
#         Date    Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13   1:00   1950      EF1                     0.2              7.0
# 1 1950-02-13   2:00   1950      EF2                     0.2              7.0
# 2 1950-03-27  15:00   1950      EF1                     0.2              7.0
# 3 1951-11-14  22:00   1951      EF2                     0.2              7.0
# 4 1952-02-13  17:00   1952      EF2                     0.3            300.0
#
#   Injury  Fatality  Property Damage Crops Damage  commnets  \
# 0      8       0.0           2500.0            0       NaN
# 1      1       9.0          25000.0            0       NaN
# 2      0       0.0           2500.0            0       NaN
# 3      0       0.0          25000.0            0       NaN
# 4      0       0.0          25000.0            0       NaN
#
#                          Link month
# 0  Feb. 13, 1950 01:00 AM CST     2
# 1  Feb. 13, 1950 02:00 AM CST     2
# 2  Mar. 27, 1950 15:00 PM CST     3
# 3  Nov. 14, 1951 22:00 PM CST    11
# 4  Feb. 13, 1952 17:00 PM CST     2

# %%
tn_torn.dtypes
# Out:
# Date                      datetime64[ns]
# Time                              object
# Year                               int64
# EF Scale                          object
# Path Length (in miles)           float64
# Width (in feet)                  float64
# Injury                            object
# Fatality                         float64
# Property Damage                  float64
# Crops Damage                      object
# commnets                         float64
# Link                              object
# month                             object
# dtype: object

# %%
tn_torn.loc[tn_torn['Crops Damage']== 'A tornado touched down along Highway 225 and Silerton Road near Montezuma and moved southeast for roughly 2 miles. Six homes were damaged with two sustaining significant damage. A roof of a church sustained minor damage. A few farm sheds were damaged as well. A camper and boat was destroyed. Trees were snapped in the area and a few vehicles sustained shattered windows. A cotton module compress was also destroyed. The tornado lifted along Cecil Thomas Road.']= 0
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_10960\2926418147.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0' has dtype incompatible with datetime64[ns], please explicitly cast to a compatible dtype first.
#   tn_torn.loc[tn_torn['Crops Damage']== 'A tornado touched down along Highway 225 and Silerton Road near Montezuma and moved southeast for roughly 2 miles. Six homes were damaged with two sustaining significant damage. A roof of a church sustained minor damage. A few farm sheds were damaged as well. A camper and boat was destroyed. Trees were snapped in the area and a few vehicles sustained shattered windows. A cotton module compress was also destroyed. The tornado lifted along Cecil Thomas Road.']= 0

# %%
tn_torn['Fatality'] = tn_torn['Fatality'].fillna(0)
tn_torn['Fatality'] = tn_torn['Fatality'].astype(int)

# %%
tn_torn['Property Damage'] = tn_torn['Property Damage'].astype(int)
tn_torn['Property Damage'] = tn_torn['Property Damage'].fillna(0)

# %%
tn_torn['Injury'] = tn_torn['Injury'].str.replace(' (1)', '')

# %%
tn_torn['Injury'] = tn_torn['Injury'].fillna(0)

# %%
tn_torn['Injury'] = tn_torn['Injury'].astype(int)

# %%
def give_me_decade_please(Year):
    if 1950 <= Year <= 1959:
        return '1950s'
    elif 1960 <= Year <= 1969:
        return '1960s'
    elif 1970 <= Year <= 1979:
        return '1970s'
    elif 1980 <= Year <= 1989:
        return '1980s'
    elif 1990 <= Year <= 1999:
        return '1990s'
    elif 2000 <= Year <= 2009:
        return '2000s'
    elif 2010 <= Year <= 2019:
        return '2010s'
    elif 2020 <= Year <= 2029:
        return '2020s'
    else:
        return 'Unknown'

tn_torn['Decade'] = tn_torn['Year'].apply(give_me_decade_please)
tn_torn
# Out:
#                      Date    Time  Year EF Scale  Path Length (in miles)  \
# 0     1950-02-13 00:00:00   1:00   1950      EF1                    0.20
# 1     1950-02-13 00:00:00   2:00   1950      EF2                    0.20
# 2     1950-03-27 00:00:00  15:00   1950      EF1                    0.20
# 3     1951-11-14 00:00:00  22:00   1951      EF2                    0.20
# 4     1952-02-13 00:00:00  17:00   1952      EF2                    0.30
# ...                   ...     ...   ...      ...                     ...
# 1573  2024-05-08 00:00:00  20:02   2024      EF1                    1.38
# 1574  2024-05-09 00:00:00  12:39   2024      EF1                    4.34
# 1575  2024-05-14 00:00:00  15:16   2024      EF0                    3.62
# 1576  2024-05-26 00:00:00  23:55   2024      EF1                   11.00
# 1577  2024-07-29 00:00:00  13:24   2024      EF0                    3.34
#
#       Width (in feet)  Injury  Fatality  Property Damage Crops Damage  \
# 0                 7.0       8         0             2500            0
# 1                 7.0       1         9            25000            0
# 2                 7.0       0         0             2500            0
# 3                 7.0       0         0            25000            0
# 4               300.0       0         0            25000            0
# ...               ...     ...       ...              ...          ...
# 1573            286.0       0         0                0            0
# 1574            300.0       0         0             3000            0
# 1575            100.0       0         0           250000            0
# 1576            550.0       0         0            10000            0
# 1577            100.0       0         0           750000            0
#
#       commnets                        Link month Decade
# 0          NaN  Feb. 13, 1950 01:00 AM CST     2  1950s
# 1          NaN  Feb. 13, 1950 02:00 AM CST     2  1950s
# 2          NaN  Mar. 27, 1950 15:00 PM CST     3  1950s
# 3          NaN  Nov. 14, 1951 22:00 PM CST    11  1950s
# 4          NaN  Feb. 13, 1952 17:00 PM CST     2  1950s
# ...        ...                         ...   ...    ...
# 1573       NaN  May. 08, 2024 20:02 PM CDT     5  2020s
# 1574       NaN  May. 09, 2024 00:39 AM CDT     5  2020s
# 1575       NaN  May. 14, 2024 15:16 PM CDT     5  2020s
# 1576       NaN  May. 26, 2024 23:55 PM CDT     5  2020s
# 1577       NaN  Jul. 29, 2024 13:24 PM CDT     7  2020s
#
# [1577 rows x 14 columns]

# %%
tn_torn = tn_torn.loc[~(tn_torn['EF Scale'] == 0)]
tn_torn['EF Scale'].value_counts()
# Out:
# EF Scale
# EF1    600
# EF0    496
# EF2    306
# EF3    120
# EF4     53
# EF5      1
# Name: count, dtype: int64

# %%
tn_torn.to_csv('tn_torn.csv', index=False)

# %%
torns_yearly = tn_torn.groupby('Year').size().reset_index(name = 'tornado_reports')
type(torns_yearly)
# Out:
# pandas.core.frame.DataFrame

# %%
torns_yearly = torns_yearly.drop(0).reset_index()
torns_yearly
# Out:
#     index  Year  tornado_reports
# 0       1  1951                1
# 1       2  1952               25
# 2       3  1953               16
# 3       4  1954                2
# 4       5  1955               15
# ..    ...   ...              ...
# 68     69  2020               41
# 69     70  2021               97
# 70     71  2022                6
# 71     72  2023               59
# 72     73  2024               14
#
# [73 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x="Year", y="tornado_reports", data = torns_yearly, palette="plasma")

plt.title("Tornado Accounts by Year", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Tornado Count", fontsize=12)
plt.xticks(rotation = 95)  
plt.tight_layout();
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_10960\2505727177.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Year", y="tornado_reports", data = torns_yearly, palette="plasma")

# %%
Injuries_per_year = tn_torn.groupby('Year')['Injury'].sum().reset_index()
Injuries_per_year = Injuries_per_year.drop(0).reset_index()
Injuries_per_year = Injuries_per_year.reset_index(drop = True)
Injuries_per_year = Injuries_per_year.drop(columns=['index'])
Injuries_per_year
# Out:
#     Year  Injury
# 0   1951       0
# 1   1952     659
# 2   1953      34
# 3   1954       4
# 4   1955      16
# ..   ...     ...
# 68  2020     337
# 69  2021      43
# 70  2022       0
# 71  2023     149
# 72  2024      13
#
# [73 rows x 2 columns]

# %%
plt.figure(figsize=(12, 6))

sns.barplot(x="Year", y="Injury", data = Injuries_per_year, palette="plasma")

plt.title("Tornado Accounts by Year", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Injuries Caused", fontsize=12)
plt.xticks(rotation = 95)  
plt.tight_layout();
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_10960\4239431305.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Year", y="Injury", data = Injuries_per_year, palette="plasma")

# %%
fatalities_per_year = tn_torn.groupby('Year')['Fatality'].sum().reset_index()
fatalities_per_year.sort_values(by = 'Fatality', ascending = False).head()
fatalities_per_year = fatalities_per_year.drop(0)
fatalities_per_year
# Out:
#     Year  Fatality
# 1   1951         0
# 2   1952        75
# 3   1953         4
# 4   1954         0
# 5   1955         0
# ..   ...       ...
# 69  2020        27
# 70  2021         4
# 71  2022         0
# 72  2023        17
# 73  2024         1
#
# [73 rows x 2 columns]

# %%
fatalities_per_decade = tn_torn.groupby('Decade')['Fatality'].sum().reset_index()
fatalities_per_decade = fatalities_per_decade.drop(8)
fatalities_per_decade
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 fatalities_per_decade = tn_torn.groupby('Decade')['Fatality'].sum().reset_index()
# ----> 2 fatalities_per_decade = fatalities_per_decade.drop(8)
#       3 fatalities_per_decade
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[8] not found in axis'

# %%
sns.scatterplot(data=fatalities_per_decade, x="Decade", y="Fatality", color = 'black')

# %%
injuries_per_decade = tn_torn.groupby('Decade')['Injury'].sum().reset_index()
injuries_per_decade = injuries_per_decade.drop(8)
injuries_per_decade
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 2
#       1 injuries_per_decade = tn_torn.groupby('Decade')['Injury'].sum().reset_index()
# ----> 2 injuries_per_decade = injuries_per_decade.drop(8)
#       3 injuries_per_decade
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: '[8] not found in axis'

# %%
sns.scatterplot(data=injuries_per_decade, x="Decade", y="Injury", color = 'green')
# Out:
# <Axes: xlabel='Decade', ylabel='Injury'>

# %%
merged = pd.merge(injuries_per_decade, fatalities_per_decade, on = 'Decade')
merged
# Out:
#   Decade  Injury  Fatality
# 0  1950s     817        91
# 1  1960s     146        11
# 2  1970s    1261        59
# 3  1980s     142         8
# 4  1990s     614        29
# 5  2000s     753       100
# 6  2010s     586        43
# 7  2020s     542        49

# %%
merged.describe()
# Out:
#             Injury    Fatality
# count     8.000000    8.000000
# mean    607.625000   48.750000
# std     363.826857   33.860006
# min     142.000000    8.000000
# 25%     443.000000   24.500000
# 50%     600.000000   46.000000
# 75%     769.000000   67.000000
# max    1261.000000  100.000000

# %%
sns.set_theme(style="whitegrid")

g = sns.catplot(
    data=merged, kind="bar",
    x="Injury", y="Fatality", hue="Decade",
    errorbar="sd", palette="dark", alpha=.6, height=6)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
tn_torn.columns
# Out:
# Index(['Date', 'Time', 'Year', 'EF Scale', 'Path Length (in miles)',
#        'Width (in feet)', 'Injury', 'Fatality', 'Property Damage',
#        'Crops Damage', 'commnets', 'Link', 'month', 'Decade'],
#       dtype='object')

# %%
tn_torn.dtypes
# Out:
# Date                       object
# Time                       object
# Year                        int64
# EF Scale                   object
# Path Length (in miles)    float64
# Width (in feet)           float64
# Injury                      int32
# Fatality                    int32
# Property Damage             int32
# Crops Damage               object
# commnets                  float64
# Link                       object
# month                      object
# Decade                     object
# dtype: object

# %%
tn_torn['Date'] = pd.to_datetime(tn_torn['Date'])
# Out:
# C:\Users\theca\AppData\Local\Temp\ipykernel_10960\1138620646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_torn['Date'] = pd.to_datetime(tn_torn['Date'])

# %%
tn_torn = tn_torn.drop(columns = 'commnets')
tn_torn.head(1)
# Out:
#         Date   Time  Year EF Scale  Path Length (in miles)  Width (in feet)  \
# 0 1950-02-13  1:00   1950      EF1                     0.2              7.0
#
#    Injury  Fatality  Property Damage Crops Damage                        Link  \
# 0       8         0             2500            0  Feb. 13, 1950 01:00 AM CST
#
#   month Decade
# 0     2  1950s

# %%
tn_torn['Crops Damage'] = tn_torn['Crops Damage'].astype(int)
tn_torn['month'] = tn_torn['month'].astype(int)

# %%
tn_torn.dtypes
# Out:
# Date                      datetime64[ns]
# Time                              object
# Year                               int64
# EF Scale                          object
# Path Length (in miles)           float64
# Width (in feet)                  float64
# Injury                             int32
# Fatality                           int32
# Property Damage                    int32
# Crops Damage                       int32
# Link                              object
# month                              int32
# Decade                            object
# dtype: object

# %%
tn_torn.columns
# Out:
# Index(['Date', 'Time', 'Year', 'EF Scale', 'Path Length (in miles)',
#        'Width (in feet)', 'Injury', 'Fatality', 'Property Damage',
#        'Crops Damage', 'Link', 'month', 'Decade'],
#       dtype='object')

# %%
tn_torn
# Out:
#            Date    Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00   1950      EF1                    0.20
# 1    1950-02-13   2:00   1950      EF2                    0.20
# 2    1950-03-27  15:00   1950      EF1                    0.20
# 3    1951-11-14  22:00   1951      EF2                    0.20
# 4    1952-02-13  17:00   1952      EF2                    0.30
# ...         ...     ...   ...      ...                     ...
# 1573 2024-05-08  20:02   2024      EF1                    1.38
# 1574 2024-05-09  12:39   2024      EF1                    4.34
# 1575 2024-05-14  15:16   2024      EF0                    3.62
# 1576 2024-05-26  23:55   2024      EF1                   11.00
# 1577 2024-07-29  13:24   2024      EF0                    3.34
#
#       Width (in feet)  Injury  Fatality  Property Damage  Crops Damage  \
# 0                 7.0       8         0             2500             0
# 1                 7.0       1         9            25000             0
# 2                 7.0       0         0             2500             0
# 3                 7.0       0         0            25000             0
# 4               300.0       0         0            25000             0
# ...               ...     ...       ...              ...           ...
# 1573            286.0       0         0                0             0
# 1574            300.0       0         0             3000             0
# 1575            100.0       0         0           250000             0
# 1576            550.0       0         0            10000             0
# 1577            100.0       0         0           750000             0
#
#                             Link  month Decade
# 0     Feb. 13, 1950 01:00 AM CST      2  1950s
# 1     Feb. 13, 1950 02:00 AM CST      2  1950s
# 2     Mar. 27, 1950 15:00 PM CST      3  1950s
# 3     Nov. 14, 1951 22:00 PM CST     11  1950s
# 4     Feb. 13, 1952 17:00 PM CST      2  1950s
# ...                          ...    ...    ...
# 1573  May. 08, 2024 20:02 PM CDT      5  2020s
# 1574  May. 09, 2024 00:39 AM CDT      5  2020s
# 1575  May. 14, 2024 15:16 PM CDT      5  2020s
# 1576  May. 26, 2024 23:55 PM CDT      5  2020s
# 1577  Jul. 29, 2024 13:24 PM CDT      7  2020s
#
# [1576 rows x 13 columns]

# %%
tornado_sql = tn_torn.rename(columns={'Date': 'date','Time': 'time','Year': 'year','EF Scale': 'ef_scale',
    'Path Length (in miles)': 'path_length_mi','Width (in feet)': 'width_mi','Injury': 'injury','Fatality': 'fatality',
    'Property Damage': 'property_dmg','Crops Damage': 'crop_dmg', 'Link': 'link','month': 'month','Decade': 'decade'})

# %%
tornado_sql.dtypes
# Out:
# date              datetime64[ns]
# time                      object
# year                       int64
# ef_scale                  object
# path_length_mi           float64
# width_mi                 float64
# injury                     int32
# fatality                   int32
# property_dmg               int32
# crop_dmg                   int32
# link                      object
# month                      int32
# decade                    object
# dtype: object

# %%
tornado_sql.columns
# Out:
# Index(['date', 'time', 'year', 'ef_scale', 'path_length_mi', 'width_mi',
#        'injury', 'fatality', 'property_dmg', 'crop_dmg', 'link', 'month',
#        'decade'],
#       dtype='object')

# %%
tn_torn
# Out:
#            Date    Time  Year EF Scale  Path Length (in miles)  \
# 0    1950-02-13   1:00   1950      EF1                    0.20
# 1    1950-02-13   2:00   1950      EF2                    0.20
# 2    1950-03-27  15:00   1950      EF1                    0.20
# 3    1951-11-14  22:00   1951      EF2                    0.20
# 4    1952-02-13  17:00   1952      EF2                    0.30
# ...         ...     ...   ...      ...                     ...
# 1573 2024-05-08  20:02   2024      EF1                    1.38
# 1574 2024-05-09  12:39   2024      EF1                    4.34
# 1575 2024-05-14  15:16   2024      EF0                    3.62
# 1576 2024-05-26  23:55   2024      EF1                   11.00
# 1577 2024-07-29  13:24   2024      EF0                    3.34
#
#       Width (in feet)  Injury  Fatality  Property Damage  Crops Damage  \
# 0                 7.0       8         0             2500             0
# 1                 7.0       1         9            25000             0
# 2                 7.0       0         0             2500             0
# 3                 7.0       0         0            25000             0
# 4               300.0       0         0            25000             0
# ...               ...     ...       ...              ...           ...
# 1573            286.0       0         0                0             0
# 1574            300.0       0         0             3000             0
# 1575            100.0       0         0           250000             0
# 1576            550.0       0         0            10000             0
# 1577            100.0       0         0           750000             0
#
#                             Link  month Decade
# 0     Feb. 13, 1950 01:00 AM CST      2  1950s
# 1     Feb. 13, 1950 02:00 AM CST      2  1950s
# 2     Mar. 27, 1950 15:00 PM CST      3  1950s
# 3     Nov. 14, 1951 22:00 PM CST     11  1950s
# 4     Feb. 13, 1952 17:00 PM CST      2  1950s
# ...                          ...    ...    ...
# 1573  May. 08, 2024 20:02 PM CDT      5  2020s
# 1574  May. 09, 2024 00:39 AM CDT      5  2020s
# 1575  May. 14, 2024 15:16 PM CDT      5  2020s
# 1576  May. 26, 2024 23:55 PM CDT      5  2020s
# 1577  Jul. 29, 2024 13:24 PM CDT      7  2020s
#
# [1576 rows x 13 columns]

# %%
tornado_sql.to_csv('tornado_for_sql_v2.csv', index=False)

# %%
nws_df =
